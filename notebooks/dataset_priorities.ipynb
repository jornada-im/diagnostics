# %%
import pandas as pd
import sys
import os
sys.path.append('/home/greg/GitHub/')
import pyEDIutils.search as edi
import datetime
import psycopg2
from sqlalchemy import create_engine
now = datetime.datetime.now().strftime("%Y%m%d")

# %%
df = edi.search_pasta(fields=['packageid','title','pubdate','author',
                                   'begindate','enddate','doi'])
df.head()
# Out:
# https://pasta.lternet.edu/package/search/eml?defType=edismax&q=%2A&fq=scope%3Aknb-lter-jrn&fl=packageid%2Ctitle%2Cpubdate%2Cauthor%2Cbegindate%2Cenddate%2Cdoi&sort=packageid%2Casc&rows=500
#                   packageid  \
# 0        knb-lter-jrn.100.3
# 1        knb-lter-jrn.101.1
# 2        knb-lter-jrn.102.1
# 3  knb-lter-jrn.200021001.5
# 4  knb-lter-jrn.200022001.3
#
#                                                title pubdate  \
# 0  High resolution shrub cover raster maps of the...    2020
# 1  Thresholds and alternative states in neotropic...    2021
# 2  Carbon exchange responses of rehydrated and in...    2023
# 3  Data to explore circular manureshed management...    2023
# 4  Criollo and Crossbred Steer Comparison: Weight...    2022
#
#                                              authors   begindate     enddate  \
# 0                         Ji, Wenjie;Hanan, Niall P.  2011-01-01  2011-12-31
# 1  Peinetti, H. Raúl;Bestelmeyer, Brandon;Chirino...  2005-09-01  2018-03-31
# 2              Hoellrich, Mikaela;Pietrasiak, Nicole  2020-01-01  2022-12-31
# 3  Spiegal, Sheri;Vendramini, João M.B.;Bittman, ...  2010-01-01  2019-12-31
# 4  McIntosh, Matt M;Cibils, Andres F;Estell, Rick...  2015-12-01  2017-01-31
#
#                                                  doi
# 0  doi:10.6073/pasta/313fec8669bc7b4d8debf7393dd2...
# 1  doi:10.6073/pasta/e1978467bd09fc4f6e0cd8509b06...
# 2  doi:10.6073/pasta/c6ffd88dc80df1ed1ec32ccdc477...
# 3  doi:10.6073/pasta/6025924b89e313f25bddf1912c8a...
# 4  doi:10.6073/pasta/66ffe320906785bb708c55a61787...

# %%
import sqlalchemy as sq
import yaml

# Get the metabase credentials
with open("/home/greg/admin/jrn_metabase_keys.yaml", "r") as stream:
    try:
        mbcred = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# Database engine
engine = sq.create_engine("postgresql+psycopg2://{0}:{1}@{2}:{3}/{4}".format(mbcred['user'],
                                                                             mbcred['password'],
                                                                             mbcred['host'],
                                                                             mbcred['port'],
                                                                             mbcred['mbname']))

# connect to the database using the newly created Engine instance
conn = engine.connect()

# run SQL query
mbdf = pd.read_sql_query(sql='SELECT * FROM lter_metabase."DataSet"', con=conn)
mbdf.head()
# Out:
#    DataSetID  Revision                                              Title  \
# 0  210011005       105  Annual ground-based photographs taken at 15 ne...
# 1  210086004       105  Leaf litter cover data on 1m x 1m plots from t...
# 2  210013001        62  Raw neutron counts from a soil water content h...
# 3  210013003        16  Soil volumetric water content calculated from ...
# 4  210011002       109  Seasonal non-destructive vegetation measuremen...
#
#       PubDate               Abstract ShortName UpdateFrequency  \
# 0  2019-10-09  abstract.210011005.md      None        annually
# 1  2022-04-11  abstract.210086004.md      None        asNeeded
# 2  2019-09-30  abstract.210013001.md      None        asNeeded
# 3  2019-10-29  abstract.210013003.md      None      notPlanned
# 4  2023-08-23  abstract.210011002.md      None        annually
#
#                        MaintenanceDescription AbstractType BoilerplateSetting
# 0                                     ongoing         file        jrn-default
# 1  ongoing - New data are added every 5 years         file        jrn-default
# 2                                     ongoing         file        jrn-default
# 3                                     ongoing         file        jrn-default
# 4                                     ongoing         file        jrn-default

# %%
df['DataSetID'] = df.packageid.str.split('.', n=2, expand=True).iloc[:,1].astype(int)

# %%
df = df.merge(mbdf[['DataSetID','MaintenanceDescription']], on='DataSetID', how='left')

# %%
pd.isnull(df.MaintenanceDescription)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 380     True
# 381    False
# 382    False
# 383    False
# 384    False
# Name: MaintenanceDescription, Length: 385, dtype: bool

# %%
# Find John's met packages and assign "ongoing"
test = (df['packageid'].str.contains('210437') | df['packageid'].str.contains('210548'))
df.loc[test, 'MaintenanceDescription'] = 'ongoing'
# Find "None" Maintenance descriptions and change to ''
test = pd.isnull(df['MaintenanceDescription'])
df.loc[test, 'MaintenanceDescription'] = ''

# %%
import numpy as np
# Create a priority column with empty values
df['priority'] = ''
# Find high priority datasets
test = np.logical_and(df['pubdate'].astype(int) < 2022, df['MaintenanceDescription'].str.contains('ongoing'))
df.loc[test, 'priority'] = 'high'
# Find low priority datasets
test = np.logical_or(df['pubdate'].astype(int) > 2021, df['MaintenanceDescription'].str.contains('complete'))
df.loc[test, 'priority'] = 'low'

# %%
df.head()
# Out:
#                   packageid  \
# 0        knb-lter-jrn.100.3
# 1        knb-lter-jrn.101.1
# 2        knb-lter-jrn.102.1
# 3  knb-lter-jrn.200021001.5
# 4  knb-lter-jrn.200022001.3
#
#                                                title pubdate  \
# 0  High resolution shrub cover raster maps of the...    2020
# 1  Thresholds and alternative states in neotropic...    2021
# 2  Carbon exchange responses of rehydrated and in...    2023
# 3  Data to explore circular manureshed management...    2023
# 4  Criollo and Crossbred Steer Comparison: Weight...    2022
#
#                                              authors   begindate     enddate  \
# 0                         Ji, Wenjie;Hanan, Niall P.  2011-01-01  2011-12-31
# 1  Peinetti, H. Raúl;Bestelmeyer, Brandon;Chirino...  2005-09-01  2018-03-31
# 2              Hoellrich, Mikaela;Pietrasiak, Nicole  2020-01-01  2022-12-31
# 3  Spiegal, Sheri;Vendramini, João M.B.;Bittman, ...  2010-01-01  2019-12-31
# 4  McIntosh, Matt M;Cibils, Andres F;Estell, Rick...  2015-12-01  2017-01-31
#
#                                                  doi  DataSetID  \
# 0  doi:10.6073/pasta/313fec8669bc7b4d8debf7393dd2...        100
# 1  doi:10.6073/pasta/e1978467bd09fc4f6e0cd8509b06...        101
# 2  doi:10.6073/pasta/c6ffd88dc80df1ed1ec32ccdc477...        102
# 3  doi:10.6073/pasta/6025924b89e313f25bddf1912c8a...  200021001
# 4  doi:10.6073/pasta/66ffe320906785bb708c55a61787...  200022001
#
#   MaintenanceDescription priority
# 0                ongoing     high
# 1                ongoing     high
# 2               complete      low
# 3               complete      low
# 4               complete      low

# %%
df.sort_values(by=['priority','pubdate'], ascending=[True, True])
# Out:
#                       packageid  \
# 271    knb-lter-jrn.210520001.1
# 28   knb-lter-jrn.210011005.105
# 29   knb-lter-jrn.210012001.139
# 30   knb-lter-jrn.210012002.127
# 31    knb-lter-jrn.210013001.62
# ..                          ...
# 378   knb-lter-jrn.210548101.28
# 379   knb-lter-jrn.210548102.27
# 380   knb-lter-jrn.210548103.28
# 383    knb-lter-jrn.210586001.3
# 384    knb-lter-jrn.210586002.3
#
#                                                  title pubdate  \
# 271  Vascular Plant Species of the Jornada Basin, 1...    2018
# 28   Annual ground-based photographs taken at 15 ne...    2019
# 29   Raw neutron counts from a soil water content h...    2019
# 30   Soil volumetric water content calculated from ...    2019
# 31   Raw neutron counts from a soil water content h...    2019
# ..                                                 ...     ...
# 378  Jornada Basin LTER Cross-scale Interactions St...    2023
# 379  Jornada Basin LTER Cross-scale Interactions St...    2023
# 380  Jornada Basin LTER Cross-scale Interactions St...    2023
# 383  Soil and foliar carbon and nitrogen content an...    2023
# 384  Dataset and analyses for publication entitled:...    2023
#
#                                                authors   begindate  \
# 271                     Anderson, John;Van Zee, Justin  1982-01-01
# 28                                      Anderson, John  2003-10-14
# 29   Wierenga, Peter;Virginia, Ross;Duniway, Michae...  1985-11-22
# 30   Wierenga, Peter;Virginia, Ross;Duniway, Michae...  1982-04-30
# 31        Virginia, Ross;Duniway, Mike;Vivoni, Enrique  1989-07-05
# ..                                                 ...         ...
# 378                                     Anderson, John  2017-08-11
# 379                                     Anderson, John  2017-08-11
# 380                                     Anderson, John  2017-08-11
# 383  Currier, Courtney;Reichmann, Lara;Sala, Osvaldo E  2011-06-01
# 384  Currier, Courtney;Reichmann, Lara;Sala, Osvaldo E  1876-01-01
#
#         enddate                                                doi  DataSetID  \
# 271  2018-09-30  doi:10.6073/pasta/6981502ed9fcf69a6bef71cc133f...  210520001
# 28   2018-09-18  doi:10.6073/pasta/69ca7ac7254a2b236d3f44b21fa8...  210011005
# 29   2019-04-30  doi:10.6073/pasta/963587e508b2b01b1bb7f8941f54...  210012001
# 30   2019-04-30  doi:10.6073/pasta/2e37c18c14eea1d1e4fccb35ed94...  210012002
# 31   2019-05-03  doi:10.6073/pasta/0f4474b774dab3d097fad39efcf5...  210013001
# ..          ...                                                ...        ...
# 378  2023-09-21  doi:10.6073/pasta/5fa75fe767589be1baaaa57e85de...  210548101
# 379  2023-09-21  doi:10.6073/pasta/e1236353b6a15d53aa8864788236...  210548102
# 380  2023-09-21  doi:10.6073/pasta/029c896133cb4571259ffe077822...  210548103
# 383  2020-09-30  doi:10.6073/pasta/8929d93801db656ae1ad0f3a12a1...  210586001
# 384  2021-12-31  doi:10.6073/pasta/f2c47d19074337832ee4e720e2a0...  210586002
#
#     MaintenanceDescription priority
# 271                ongoing     high
# 28                 ongoing     high
# 29                 ongoing     high
# 30                 ongoing     high
# 31                 ongoing     high
# ..                     ...      ...
# 378                ongoing      low
# 379                ongoing      low
# 380                ongoing      low
# 383                ongoing      low
# 384               complete      low
#
# [385 rows x 10 columns]

# %%
df.sort_values(by=['priority','pubdate'], ascending=[True, True]).to_csv('tables_out/jrn_edi_catalog_bypubdate_20231103.csv')
